# %%
import os
os.environ["LCLS_LATTICE"] = "/sdf/group/ad/sw/scm/repos/optics/lcls-lattice/"

# %%
os.environ["LCLS_LATTICE"] = "/sdf/group/ad/sw/scm/repos/optics/lcls-lattice/"
os.environ["SCRATCH"]="/sdf/home/m/mokun/SCRATCH"
os.environ["LUME_IMPACT_CODEBASE_LOCATION"]="/sdf/home/m/mokun/code/lume-repos/lume-impact-live-demo"
os.environ["LUME_OUTPUT_FOLDERS"]="/sdf/home/m/mokun/lume-output"

# %%
# !echo $LUME_OUTPUT_FOLDERS
# Out:
# /sdf/home/m/mokun/lume-output

# %% [markdown]
# # Live cu-inj-live-impact

# %%
# !echo $LCLS_LATTICE
# Out:
# /sdf/group/ad/sw/scm/repos/optics/lcls-lattice/

# %%
# !caget KLYS:LI22:11:KPHR
# Out:
# KLYS:LI22:11:KPHR              31.3509

# %%
# Setup directories, and convert dashboard notebook to a script for importing
#!./setup.bash
print("Running LUME IMPACT SERVICE.....")
# Out:
# Running LUME IMPACT SERVICE.....

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from impact import evaluate_impact_with_distgen, run_impact_with_distgen
from impact.tools import isotime
from impact.evaluate import  default_impact_merit
from impact import Impact
import os

from make_dashboard import make_dashboard
from get_vcc_image import get_live_distgen_xy_dist, VCC_DEVICE_PV

from lcls_live.tools import NpEncoder

import matplotlib as mpl

from pmd_beamphysics.units import e_charge

# %%
import pandas as pd
import numpy as np

import h5py
import json
import epics

import sys
import os
import toml
from time import sleep, time
import datetime


import matplotlib.pyplot as plt

import matplotlib as mpl
mpl.use('Agg')

# Nicer plotting
# %config InlineBackend.figure_format = 'retina'

# %%
#Sanity Checks for OS Environments
if 'LCLS_LATTICE' in os.environ:
    print('LCLS Lattice is set to - ', os.environ['LCLS_LATTICE'])
else:
    print('LCLS_LATTICE Location is missing')
    exit(1)
if 'LUME_OUTPUT_FOLDERS' in os.environ:
    print('LUME_OUTPUT_FOLDERS is set to - ', os.environ['LUME_OUTPUT_FOLDERS'])
else:
    print('LUME_OUTPUT_FOLDERS Location is missing')
    exit(1)
if 'SCRATCH' in os.environ:
    print('SCRATCH is set to - ', os.environ['SCRATCH'])
else:
    print('SCRATCH Location is missing')
    exit(1)

def replaceEnvironmentFiles(file_location):
    if 'LUME_OUTPUT_FOLDERS' in file_location:
        return file_location.replace('$LUME_OUTPUT_FOLDERS', os.environ['LUME_OUTPUT_FOLDERS'])
    if 'LCLS_LATTICE' in file_location:
        return file_location.replace('$LCLS_LATTICE', os.environ['LCLS_LATTICE'])
    if 'SCRATCH' in file_location:
        return file_location.replace('$SCRATCH', os.environ['SCRATCH'])
    return file_location
# Out:
# LCLS Lattice is set to -  /sdf/group/ad/sw/scm/repos/optics/lcls-lattice/
# LUME_OUTPUT_FOLDERS is set to -  /sdf/home/m/mokun/lume-output
# SCRATCH is set to -  /sdf/home/m/mokun/SCRATCH

# %% [markdown]
# # Top level config

# %%
import argparse

parser = argparse.ArgumentParser()
parser.add_argument("-d", "--debug", help = "Debug Mode", default = False)
parser.add_argument("-v", "--use_vcc", help = "Use VCC - True When VCC is Active", default = True)
parser.add_argument("-l", "--live", help = "Live Mode -  True When BEAM is Active", default = True)
parser.add_argument("-m", "--model", help = "Mention the Injector Model", default = "sc_inj")
parser.add_argument("-t", "--host", help = "Mention the host", default = "singularity")
parser.add_argument("-p", "--num_procs", help = "Mention the Num Procs", default = 64)
# Out:
# _StoreAction(option_strings=['-p', '--num_procs'], dest='num_procs', nargs=None, const=None, default=64, type=None, choices=None, required=False, help='Mention the Num Procs', metavar=None)

# %%
def convertStringToBoolean(argument):
    if argument == 'True' or argument == 'true' or argument == True:
        return True
    else:
        return False

# %%
#%tb
#args = vars(parser.parse_args())

#DEBUG = convertStringToBoolean(args['debug'])
#USE_VCC = convertStringToBoolean(args['use_vcc'])
#LIVE = convertStringToBoolean(args['live'])
#MODEL = args['model']
#HOST = args['host']
#NUM_PROCS_ARGS = int(args['num_procs'])

DEBUG = False
USE_VCC = True
USE_SAVED_VCC = False
SAVED_VCC = "/sdf/group/ad/beamphysics/jytang/lume-impact-live-demo/configs/vcc_image/laser_06032024.txt"
LIVE = True
MODEL = "sc_inj"
HOST = 's3df'
NUM_PROCS_ARGS = 64

SNAPSHOT = 'examples/sc_inj-snapshot-2022-11-12T12:38:08-08:00.h5'
MIN_CHARGE_pC = 10
config = toml.load(f"configs/{HOST}_{MODEL}.toml")
PREFIX = f'lume-impact-live-demo-{HOST}-{MODEL}'

# %%
def convertToDatedFormat(destionation_folder):
    curr_date = datetime.date.today()
    year,month,day = curr_date.strftime('%Y'),curr_date.strftime('%m'),curr_date.strftime('%d')
    destionation_folder_dated = destionation_folder + "/" + year + "/" + month + "/" + day

    if not os.path.exists(destionation_folder_dated):
        os.makedirs(destionation_folder_dated)
    
    return destionation_folder_dated

# %% [markdown]
# ## Logging

# %%
import logging
from logging.handlers import RotatingFileHandler

# Gets or creates a logger
logger = logging.getLogger(PREFIX)  

# set log level
logger.setLevel(logging.INFO)

LOG_OUTPUT_DIR = config.get("log_output_dir")
LOG_OUTPUT_DIR = replaceEnvironmentFiles(LOG_OUTPUT_DIR)
# define file handler and set formatter
file_handler = RotatingFileHandler(f'{LOG_OUTPUT_DIR}/{PREFIX}.log', mode='a', encoding=None, maxBytes=50*1024*1024, 
                                 backupCount=2, delay=0)
formatter    = logging.Formatter(fmt="%(asctime)s :  %(name)s : %(message)s ", datefmt="%Y-%m-%dT%H:%M:%S%z")

# Add print to stdout
logger.addHandler(logging.StreamHandler(sys.stdout))

file_handler.setFormatter(formatter)

# add file handler to logger
logger.addHandler(file_handler)

# %%
#Arguments -

logger.info('Start of Script Marker - Script Running with Arguments - ')
logger.info(f'Debug - {DEBUG}')
logger.info(f'USE_VCC - {USE_VCC}')
logger.info(f'LIVE - {LIVE}')
logger.info(f'MODEL - {MODEL}')
logger.info(f'HOST - {HOST}')
logger.info(f'NUM_PROCS_ARGS - {NUM_PROCS_ARGS}')
logger.info(f'Config TOML Loaded - {config}')
# Out:
# Start of Script Marker - Script Running with Arguments -
# Debug - False
# USE_VCC - True
# LIVE - True
# MODEL - sc_inj
# HOST - s3df
# NUM_PROCS_ARGS - 64
# Config TOML Loaded - {'host': 'sdf', 'config_file': '/$LCLS_LATTICE/impact/models/sc_inj/v1/ImpactT.yaml', 'distgen_input_file': '/$LCLS_LATTICE/distgen/models/sc_inj/vcc_image/distgen.yaml', 'workdir': '$SCRATCH', 'summary_output_dir': '/$LUME_OUTPUT_FOLDERS/summary', 'plot_output_dir': '/$LUME_OUTPUT_FOLDERS/plot', 'log_output_dir': '/$LUME_OUTPUT_FOLDERS/log', 'archive_dir': '/$LUME_OUTPUT_FOLDERS/archive', 'snapshot_dir': '/$LUME_OUTPUT_FOLDERS/snapshot', 'scan_output_dir': '/$LUME_OUTPUT_FOLDERS/scan', 'distgen_laser_file': '/sdf/group/ad/beamphysics/lcls-lattice/distgen_laser.txt', 'num_procs': 64, 'mpi_run_cmd': 'salloc --partition milano --account ad:ard-online -N 1 -n {nproc} mpirun -n {nproc} {command_mpi}', 'impact_command': '~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe', 'impact_command_mpi': '~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi'}

# %% [markdown]
# ## Utils

# %%
# Saving and loading
def save_pvdata(filename, pvdata, isotime):
    with h5py.File(filename, 'w') as h5:
        h5.attrs['isotime'] = np.bytes_(isotime)
        for k, v in pvdata.items():
            if isinstance(v, str):
                v =  np.bytes_(v)
            h5[k] = v 
def load_pvdata(filename):
    
    if not os.path.exists(filename):
        raise ValueError(f'H5 file does not exist: {filename} ')
    pvdata = {}
    with h5py.File(filename, 'r') as h5:
        isotime = h5.attrs['isotime']
        for k in h5:
            v = np.array(h5[k])        
            if v.dtype.char == 'S':
                v = str(v.astype(str))
            pvdata[k] = v
            
    return pvdata, isotime

# %% [markdown]
# # Configuration
#
# Set up basic input sources and output path, loaded from toml environment file.
#
# See README for required toml definition.

# %%
HOST = config.get('host') # mcc-simul or 'sdf'
if not HOST:
    raise ValueError("host not defined in toml.")
    
def get_path(key):
    val = config.get(key)
    if not val:
        raise ValueError(f"{key} not defined in toml.")
    val=os.path.expandvars(val)
    if not os.path.exists(val):
        raise ValueError(f"{val} does not exist")
    return os.path.abspath(val)


# Output dirs

SUMMARY_OUTPUT_DIR = replaceEnvironmentFiles(get_path('summary_output_dir'))
ARCHIVE_DIR = replaceEnvironmentFiles(get_path('archive_dir'))
SNAPSHOT_DIR = replaceEnvironmentFiles(get_path('snapshot_dir'))

# Dummy file for distgen
DISTGEN_LASER_FILE = config.get('distgen_laser_file')
if not DISTGEN_LASER_FILE:
    raise ValueError("distgen_laser_file not defined in toml.")

# Number of processors
NUM_PROCS = config.get('num_procs')
if not NUM_PROCS:
    raise ValueError("num_procs not defined in toml.")
else:
    NUM_PROCS = int(NUM_PROCS)

if NUM_PROCS_ARGS != NUM_PROCS:
    NUM_PROCS = NUM_PROCS_ARGS

# if using sdf:
if HOST == 'sdf':    
    #check that environment variables are configured for execution
    IMPACT_COMMAND = config.get("impact_command")
    if not IMPACT_COMMAND:
       raise ValueError("impact_command not defined in toml.")


    IMPACT_COMMAND_MPI = config.get("impact_command_mpi")
    if not IMPACT_COMMAND_MPI:
       raise ValueError("impact_command_mpi not defined in toml.")

# %%
CONFIG0 = {}

# Base settings
SETTINGS0 = {
 'distgen:n_particle': 10_000,   
 'timeout': 10000,
 'header:Nx': 32,
 'header:Ny': 32,
 'header:Nz': 32,
 'numprocs': NUM_PROCS,
   }

SETTINGS0['numprocs'] = NUM_PROCS
CONFIG0["workdir"] = replaceEnvironmentFiles(get_path('workdir'))

if DEBUG:
    logger.info('DEBUG MODE: Running without space charge for speed. ')
    SETTINGS0['distgen:n_particle'] = 1000
    SETTINGS0['total_charge'] = 0
    
# Host config    
if HOST in ('sdf'):
    
    #SDF setup 
    SETTINGS0['command'] =  IMPACT_COMMAND
    SETTINGS0['command_mpi'] =  IMPACT_COMMAND_MPI
    SETTINGS0['mpi_run'] = config.get("mpi_run_cmd")
    
elif HOST == 'local':
    logger.info('Running locally')
    
else:
    raise ValueError(f'Unknown host: {HOST}')

# %% [markdown]
# # Select: LCLS or FACET

# %%
# PV -> Sim conversion table
CSV =  f'pv_mapping/{MODEL}_impact.csv'  

CONFIG0['impact_config']      =  replaceEnvironmentFiles(get_path('config_file'))
CONFIG0['distgen_input_file'] =  replaceEnvironmentFiles(get_path('distgen_input_file'))

print('Impact Config Loaded - ', CONFIG0['impact_config'] )
print('Distgen Input File Loaded - ', CONFIG0['distgen_input_file'] )

PLOT_OUTPUT_DIR = replaceEnvironmentFiles(get_path('plot_output_dir'))

if MODEL == 'cu_inj':
    VCC_DEVICE = 'CAMR:IN20:186' # LCLS   
    
    DASHBOARD_KWARGS = {'outpath':PLOT_OUTPUT_DIR,
                    'screen1': 'YAG02',
                    'screen2': 'YAG03',
                    'screen3': 'OTR2',
                    'ylim' : (0, None), # Emittance scale   
                    'ylim2': (0, None), # sigma_x scale
                    'name' : PREFIX
                   }    
    
    SETTINGS0['stop'] = 16.5
    SETTINGS0['distgen:t_dist:length:value'] =  4 * 1.65   #  Inferred pulse stacker FWHM: 4 ps, converted to tukey length
    
if MODEL == 'sc_inj':
    VCC_DEVICE = 'CAMR:LGUN:950' # LCLS-II 
    
    DASHBOARD_KWARGS = {'outpath':PLOT_OUTPUT_DIR,
                    'screen1': 'YAG01B',
                  #  'screen2': 'BEAM0',
                  #  'screen3': 'OTR0H04',
                    'screen2': 'CM01BEG',
                    'screen3': 'BEAM0',
                    'ylim' : (0, 3e-6), # Emittance scale   
                    'ylim2': (0, None), # sigma_x scale                    
                    'name' : PREFIX
                   }    
    
    SETTINGS0['stop'] = 14 # 28
    SETTINGS0['distgen:t_dist:sigma_t:value'] =  16 / 2.355   # ps, equivalent to 16ps FWHM from Feng
    
elif MODEL == 'f2e_inj':
    VCC_DEVICE = 'CAMR:LT10:900' # FACET-II
    
    DASHBOARD_KWARGS = {'outpath':PLOT_OUTPUT_DIR,
                    'screen1': 'PR10241',
                    'screen2': 'PR10465',
                    'screen3': 'PR10571',
                    'ylim' : (0, 20e-6), # Emittance scale
                    'name' : PREFIX
                   }        
    
    SETTINGS0['distgen:t_dist:length:value'] =  3.65 * 1.65   #  Measured FWHM: 3.65 ps, converted to tukey length
     
else:
    raise
# Out:
# Impact Config Loaded -  //sdf/group/ad/sw/scm/repos/optics/lcls-lattice/impact/models/sc_inj/v1/ImpactT.yaml
# Distgen Input File Loaded -  //sdf/group/ad/sw/scm/repos/optics/lcls-lattice/distgen/models/sc_inj/vcc_image/distgen.yaml

# %%
CONFIG0, SETTINGS0
logger.info(f'FINAL SETTINGS - {SETTINGS0}')
# Out:
# FINAL SETTINGS - {'distgen:n_particle': 10000, 'timeout': 10000, 'header:Nx': 32, 'header:Ny': 32, 'header:Nz': 32, 'numprocs': 64, 'command': '~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe', 'command_mpi': '~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi', 'mpi_run': 'salloc --partition milano --account ad:ard-online -N 1 -n {nproc} mpirun -n {nproc} {command_mpi}', 'stop': 14, 'distgen:t_dist:sigma_t:value': 6.794055201698514}

# %% [markdown]
# # Set up monitors

# %%
# Gun: 700 kV
# Buncher: 200 keV energy gain
# Buncher: +60 deg relative to on-crest

# %%
DF = pd.read_csv(CSV)#.dropna()

PVLIST = list(DF['device_pv_name'].dropna()) 

if USE_VCC:
    PVLIST = PVLIST + list(VCC_DEVICE_PV[VCC_DEVICE].values())
else:
    logger.info('USE VCC set to False. VCC is not working right now.')
#DF.set_index('device_pv_name', inplace=True)
DF
# Out:
#             Variable bmad_name          device_pv_name      pv_unit  \
# 0        Gun Voltage    RFGUNB      SOLN:GUNB:212:BACT          xxx
# 1          Gun phase    RFGUNB      SOLN:GUNB:212:BACT          xxx
# 2         Solenoid 1     SOL1B      SOLN:GUNB:212:BACT         kG*m
# 3         Solenoid 2     SOL2B      SOLN:GUNB:823:BACT         kG*m
# 4             charge   CATHODE      BPMS:GUNB:314:TMIT  n_electrons
# 5    Buncher Voltage     BUN1B      ACCL:GUNB:455:AACT           MV
# 6      Buncher Phase     BUN1B      ACCL:GUNB:455:PACT          deg
# 7   Cavity 1 voltage   CAVL011  ACCL:L0B:0110:AACTMEAN           MV
# 8   Cavity 2 voltage   CAVL012  ACCL:L0B:0120:AACTMEAN           MV
# 9   Cavity 3 voltage   CAVL013  ACCL:L0B:0130:AACTMEAN           MV
# 10  Cavity 4 voltage   CAVL014  ACCL:L0B:0140:AACTMEAN           MV
# 11  Cavity 5 voltage   CAVL015  ACCL:L0B:0150:AACTMEAN           MV
# 12  Cavity 6 voltage   CAVL016  ACCL:L0B:0160:AACTMEAN           MV
# 13  Cavity 7 voltage   CAVL017  ACCL:L0B:0170:AACTMEAN           MV
# 14  Cavity 8 voltage   CAVL018  ACCL:L0B:0180:AACTMEAN           MV
# 15    Cavity 1 phase   CAVL011  ACCL:L0B:0110:PACTMEAN          deg
# 16    Cavity 2 phase   CAVL012  ACCL:L0B:0120:PACTMEAN          deg
# 17    Cavity 3 phase   CAVL013  ACCL:L0B:0130:PACTMEAN          deg
# 18    Cavity 4 phase   CAVL014  ACCL:L0B:0140:PACTMEAN          deg
# 19    Cavity 5 phase   CAVL015  ACCL:L0B:0150:PACTMEAN          deg
# 20    Cavity 6 phase   CAVL016  ACCL:L0B:0160:PACTMEAN          deg
# 21    Cavity 7 phase   CAVL017  ACCL:L0B:0170:PACTMEAN          deg
# 22    Cavity 8 phase   CAVL018  ACCL:L0B:0180:PACTMEAN          deg
# 23       Q0H01 field     Q0H01       QUAD:HTR:120:BACT         kG*m
# 24       Q0H02 field     Q0H02       QUAD:HTR:140:BACT         kG*m
# 25       Q0H03 field     Q0H03       QUAD:HTR:300:BACT         kG*m
# 26       Q0H04 field     Q0H04       QUAD:HTR:320:BACT         kG*m
# 27       Q0H05 field     Q0H05       QUAD:HTR:365:BACT         kG*m
# 28       Q0H06 field     Q0H06       QUAD:HTR:385:BACT         kG*m
# 29       Q0H07 field     Q0H07       QUAD:HTR:440:BACT         kG*m
# 30       Q0H08 field     Q0H08       QUAD:HTR:460:BACT         kG*m
#
#                    impact_name  impact_factor  impact_offset  \
# 0        RFGUNB:rf_field_scale   0.000000e+00   1.764633e+07
# 1         RFGUNB:autophase_deg   0.000000e+00   0.000000e+00
# 2   SOL1B:solenoid_field_scale   1.159555e+00   0.000000e+00
# 3   SOL2B:solenoid_field_scale   1.159555e+00   0.000000e+00
# 4   distgen:total_charge:value   1.600000e-07   0.000000e+00
# 5         BUN1B:rf_field_scale   0.000000e+00   1.786301e+06
# 6          BUN1B:autophase_deg   0.000000e+00  -6.000000e+01
# 7       CAVL011:rf_field_scale   1.861947e+06   0.000000e+00
# 8       CAVL012:rf_field_scale   1.861947e+06   0.000000e+00
# 9       CAVL013:rf_field_scale   1.861947e+06   0.000000e+00
# 10      CAVL014:rf_field_scale   1.861947e+06   0.000000e+00
# 11      CAVL015:rf_field_scale   1.861947e+06   0.000000e+00
# 12      CAVL016:rf_field_scale   1.861947e+06   0.000000e+00
# 13      CAVL017:rf_field_scale   1.861947e+06   0.000000e+00
# 14      CAVL018:rf_field_scale   1.861947e+06   0.000000e+00
# 15       CAVL011:autophase_deg   1.000000e+00   0.000000e+00
# 16       CAVL012:autophase_deg   1.000000e+00   0.000000e+00
# 17       CAVL013:autophase_deg   1.000000e+00   0.000000e+00
# 18       CAVL014:autophase_deg   1.000000e+00   0.000000e+00
# 19       CAVL015:autophase_deg   1.000000e+00   0.000000e+00
# 20       CAVL016:autophase_deg   1.000000e+00   0.000000e+00
# 21       CAVL017:autophase_deg   1.000000e+00   0.000000e+00
# 22       CAVL018:autophase_deg   1.000000e+00   0.000000e+00
# 23           Q0H01:b1_gradient  -8.038585e-01   0.000000e+00
# 24           Q0H02:b1_gradient  -8.038585e-01   0.000000e+00
# 25           Q0H03:b1_gradient  -8.038585e-01   0.000000e+00
# 26           Q0H04:b1_gradient  -8.038585e-01   0.000000e+00
# 27           Q0H05:b1_gradient  -8.038585e-01   0.000000e+00
# 28           Q0H06:b1_gradient  -8.038585e-01   0.000000e+00
# 29           Q0H07:b1_gradient  -8.038585e-01   0.000000e+00
# 30           Q0H08:b1_gradient  -8.038585e-01   0.000000e+00
#
#              impact_description impact_unit
# 0             Value for 670 kV          V/m
# 1                           NaN         deg
# 2                    peak field           T
# 3                    peak field           T
# 4       total charge on cathode          pC
# 5             values for 200 kV         V/m
# 6    phase relative to on-crest         deg
# 7   peak on-axis electric field         V/m
# 8   peak on-axis electric field         V/m
# 9   peak on-axis electric field         V/m
# 10  peak on-axis electric field         V/m
# 11  peak on-axis electric field         V/m
# 12  peak on-axis electric field         V/m
# 13  peak on-axis electric field         V/m
# 14  peak on-axis electric field         V/m
# 15   phase relative to on-crest         deg
# 16   phase relative to on-crest         deg
# 17   phase relative to on-crest         deg
# 18   phase relative to on-crest         deg
# 19   phase relative to on-crest         deg
# 20   phase relative to on-crest         deg
# 21   phase relative to on-crest         deg
# 22   phase relative to on-crest         deg
# 23      magnetic field gradient         T/m
# 24      magnetic field gradient         T/m
# 25      magnetic field gradient         T/m
# 26      magnetic field gradient         T/m
# 27      magnetic field gradient         T/m
# 28      magnetic field gradient         T/m
# 29      magnetic field gradient         T/m
# 30      magnetic field gradient         T/m

# %%
if LIVE:
    MONITOR = {pvname:epics.PV(pvname) for pvname in PVLIST}
    MONITOR.pop('ACCL:GUNB:455:AACT_AVG', None)
    MONITOR.pop('ACCL:GUNB:455:PACT_AVG', None)
    SNAPSHOT = None
    sleep(5)

# %%
buncher_voltage = 190
variablex = "Buncher Voltage"
DF.loc[DF["Variable"] == variablex, 'impact_offset' ] = 1786301.125*buncher_voltage/200
DF.loc[DF["Variable"] == variablex, 'impact_description' ] = f'Value for {buncher_voltage} kV'

variablex = "Gun Voltage"
gun_energy = 650
DF.loc[DF["Variable"] == variablex, 'impact_offset' ] = 16994214.42418604*gun_energy/670
DF.loc[DF["Variable"] == variablex, 'impact_description' ] = f'Value for {gun_energy} kV'

variablex = "Buncher Phase"
DF.loc[DF["Variable"] == variablex, 'impact_offset' ] = -57

# %%
def get_snapshot(snapshot_file=None):
        
    if LIVE:
        itime = isotime()
        pvdata =  {k:MONITOR[k].get() for k in MONITOR}
        pvdata['ACCL:GUNB:455:AACT_AVG'] = 0.0
        pvdata['ACCL:GUNB:455:PACT_AVG'] = 0.0
    else:
        pvdata, itime = load_pvdata(snapshot_file)
        itime = itime.decode('utf-8')
    
    logger.info(f'Acquired settings from EPICS at: {itime}')
    
    epics_working_check = [val for val in pvdata.values() if val is None]
    
    if len(epics_working_check) == len(list(pvdata.keys())):
        raise Exception(f'EPICS returned None for all keys. Please check if you are able to connect to Accelerator')

    VCC_Key = None
    
    for k, v in pvdata.items():
        
        if v is None:
            raise ValueError(f'EPICS get for {k} returned None')
        
        if ':IMAGE:ARRAYDATA' in k.upper():
            VCC_Key = k
            found = False
            logger.info(f'Waiting for good {k}')
            counter = 0
            USE_VCC_LOCAL = True
            while not found and counter < 5:
                counter += 1
                if v is None:
                    continue
                if v.std() > 10:
                    found = True
                else:
                    v = MONITOR[k].get()
            if counter == 5:
                logger.info(f'VCC is not working. Defaulting to None.')
                USE_VCC_LOCAL = False
            elif np.ptp(v) < 128:
                v = v.astype(np.int8) # Downcast preemptively 
            pvdata[k] = v
        else:
            USE_VCC_LOCAL = False

    if not USE_VCC_LOCAL and VCC_Key in pvdata:
        del pvdata[VCC_Key]

    return pvdata, itime, USE_VCC_LOCAL

# %% [markdown]
# # EPICS -> Simulation settings

# %%
VCC_DEVICE
# Out:
# 'CAMR:LGUN:950'

# %%
def get_settings(csv, base_settings={}, snapshot_dir=None, snapshot_file=None):
    """
    Fetches live settings for all devices in the CSV table, and translates them to simulation inputs
     
    """
    df = DF[DF['device_pv_name'].notna()]
    assert len(df) > 0, 'Empty dataframe!'
    
    pv_names = list(df['device_pv_name'])

    pvdata, itime, USE_VCC_LOCAL = get_snapshot(snapshot_file)
    
    df['pv_value'] = [pvdata[k] for k in pv_names]
    
    # Assign impact
    df['impact_value'] = df['impact_factor']*df['pv_value'] 
    if 'impact_offset' in df:
        df['impact_value'] = df['impact_value']  + df['impact_offset']

    # Collect settings
    settings = base_settings.copy()
    settings.update(dict(zip(df['impact_name'], df['impact_value'])))
    
    if DEBUG:
        settings['total_charge'] = 0
    else:
        settings['total_charge'] = 1 # Will be updated with particles

    # VCC image
    if USE_VCC_LOCAL:
        logger.info('Getting VCC Live Distgen')
        dfile, img, cutimg = get_live_distgen_xy_dist(filename=DISTGEN_LASER_FILE, vcc_device=VCC_DEVICE, pvdata=pvdata)  
        settings['distgen:xy_dist:file'] = dfile
    elif USE_SAVED_VCC:
        settings['distgen:xy_dist:file'] = SAVED_VCC
        img, cutimg = None, None
    else:
        img, cutimg = None, None
        #settings['distgen:r_dist:max_r:value'] = 0.35 # TEMP     
        
    if snapshot_dir and not snapshot_file:
        filename = os.path.abspath(os.path.join(snapshot_dir, f'{MODEL}-snapshot-{itime}.h5'))
        total_charge_pC = settings['distgen:total_charge:value']
        if total_charge_pC < MIN_CHARGE_pC:
            logger.info(f'total charge is too low: {total_charge_pC:.2f} pC, not saving snapshot')         
        else:
            save_pvdata(filename, pvdata, itime)
            logger.info(f'EPICS shapshot written: {filename}')
        
        
    return settings, df, img, cutimg, itime

# %%
DO_TIMING = False

if DO_TIMING:
    import numpy as np
    import time
    results = []
    tlist = []
    nlist = 2**np.arange(1,8, 1)[::-1]
    for n in nlist:
        t1 = time.time()
        LIVE_SETTINGS['numprocs'] = n
        print(f'running wit {n}')
        result = run_impact_with_distgen(LIVE_SETTINGS, **CONFIG0, verbose=False )
        results.append(result)
        dt = time.time() - t1
        tlist.append(dt)
        print(n, dt)     
        
    tlist, nlist

# %% [markdown]
# # Get live values, run Impact-T, make dashboard

# %%
# Patch this into the function below for the dashboard creation
def my_merit(impact_object, itime):
    # Collect standard output statistics
    merit0 = default_impact_merit(impact_object)
    
    PLOT_OUTPUT_DIR_DATED = convertToDatedFormat(PLOT_OUTPUT_DIR)
    #Overriding at runtime to save in dated folders
    DASHBOARD_KWARGS["outpath"] = PLOT_OUTPUT_DIR_DATED
    
    # Make the dashboard from the evaluated object
    plot_file = make_dashboard(impact_object, itime=itime, **DASHBOARD_KWARGS)
    #print('Dashboard written:', plot_file)
    logger.info(f'Dashboard written: {plot_file}')
    
    # Make all readable
    os.chmod(plot_file, 0o644)
    
    # Assign extra info
    merit0['plot_file'] = plot_file    
    merit0['isotime'] = itime
    
    # Clear any buffers
    plt.close('all')

    return merit0

# %%
dat = {}

SNAPSHOT_DIR_DATED = convertToDatedFormat(SNAPSHOT_DIR)
ARCHIVE_DIR_DATED = convertToDatedFormat(ARCHIVE_DIR)
SUMMARY_OUTPUT_DIR_DATED = convertToDatedFormat(SUMMARY_OUTPUT_DIR)
mysettings, df, img, cutimg, itime = get_settings(CSV,
                                                           SETTINGS0,
                                                           snapshot_dir=SNAPSHOT_DIR_DATED,
                                                          snapshot_file=SNAPSHOT)
# Out:
# Acquired settings from EPICS at: 2024-11-13T16:50:10-08:00
# Waiting for good CAMR:LGUN:950:Image:ArrayData
# EPICS shapshot written: //sdf/home/m/mokun/lume-output/snapshot/2024/11/13/sc_inj-snapshot-2024-11-13T16:50:10-08:00.h5

# %%
mysettings
# Out:
# {'distgen:n_particle': 10000,
#  'timeout': 10000,
#  'header:Nx': 32,
#  'header:Ny': 32,
#  'header:Nz': 32,
#  'numprocs': 64,
#  'command': '~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe',
#  'command_mpi': '~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi',
#  'mpi_run': 'salloc --partition milano --account ad:ard-online -N 1 -n {nproc} mpirun -n {nproc} {command_mpi}',
#  'stop': 14,
#  'distgen:t_dist:sigma_t:value': 6.794055201698514,
#  'RFGUNB:rf_field_scale': 16486924.441374516,
#  'RFGUNB:autophase_deg': 0.0,
#  'SOL1B:solenoid_field_scale': 0.051368842388835954,
#  'SOL2B:solenoid_field_scale': 0.02902505616926497,
#  'distgen:total_charge:value': 73.11480832,
#  'BUN1B:rf_field_scale': 1696986.06875,
#  'BUN1B:autophase_deg': -57.0,
#  'CAVL011:rf_field_scale': 12119176.710208839,
#  'CAVL012:rf_field_scale': 9322056.811160112,
#  'CAVL013:rf_field_scale': 20323607.827777237,
#  'CAVL014:rf_field_scale': 9322198.500932148,
#  'CAVL015:rf_field_scale': 22934135.927986793,
#  'CAVL016:rf_field_scale': 30951732.942854337,
#  'CAVL017:rf_field_scale': 30019070.073611915,
#  'CAVL018:rf_field_scale': 30951631.820656545,
#  'CAVL011:autophase_deg': -0.0014732030263916451,
#  'CAVL012:autophase_deg': 0.0007158295354372235,
#  'CAVL013:autophase_deg': -0.000858528800392758,
#  'CAVL014:autophase_deg': -0.0011354601863331204,
#  'CAVL015:autophase_deg': -5.049999891565404e-05,
#  'CAVL016:autophase_deg': -4.999400481025287,
#  'CAVL017:autophase_deg': -12.494050646443219,
#  'CAVL018:autophase_deg': 12.109471348518852,
#  'Q0H01:b1_gradient': 2.0101252123028908,
#  'Q0H02:b1_gradient': -1.81590467013481,
#  'Q0H03:b1_gradient': -0.790552607832756,
#  'Q0H04:b1_gradient': 1.5857328062088196,
#  'Q0H05:b1_gradient': 1.9301675820456787,
#  'Q0H06:b1_gradient': -0.5489706572939368,
#  'Q0H07:b1_gradient': -2.305417560504469,
#  'Q0H08:b1_gradient': 2.434405589833293,
#  'total_charge': 1}

# %%
def run1():
    dat = {}

    SNAPSHOT_DIR_DATED = convertToDatedFormat(SNAPSHOT_DIR)
    ARCHIVE_DIR_DATED = convertToDatedFormat(ARCHIVE_DIR)
    SUMMARY_OUTPUT_DIR_DATED = convertToDatedFormat(SUMMARY_OUTPUT_DIR)
        
    # Acquire settings
    mysettings, df, img, cutimg, itime = get_settings(CSV,
                                                           SETTINGS0,
                                                           snapshot_dir=SNAPSHOT_DIR_DATED,
                                                          snapshot_file=SNAPSHOT)        
    dat['isotime'] = itime
    
    # Record inputs
    dat['inputs'] = mysettings
    dat['config'] = CONFIG0
    dat['pv_mapping_dataframe'] = df.to_dict()
    
    logger.info(f'Running evaluate_impact_with_distgen...')

    t0 = time()
    
    total_charge_pC = mysettings['distgen:total_charge:value']
    if total_charge_pC < MIN_CHARGE_pC:
        logger.info(f'total charge is too low: {total_charge_pC:.2f} pC, skipping')
        return dat
    
    outputs = evaluate_impact_with_distgen(mysettings,
                                       merit_f=lambda x: my_merit(x, itime),
                                       archive_path=ARCHIVE_DIR_DATED,
                                       **CONFIG0, verbose=True )
    
    dat['outputs'] =  outputs   
    logger.info(f'...finished in {(time()-t0)/60:.1f} min')
    fname = fname=f'{SUMMARY_OUTPUT_DIR_DATED}/{PREFIX}-{itime}.json'

    json.dump(dat, open(fname, 'w'), cls=NpEncoder)
    logger.info(f'Summary output written: {fname}')
    return dat

# %% [markdown]
# # loop it

# %%
result = run1()
# Out:
# Acquired settings from EPICS at: 2024-11-13T16:50:21-08:00
# Waiting for good CAMR:LGUN:950:Image:ArrayData
# EPICS shapshot written: //sdf/home/m/mokun/lume-output/snapshot/2024/11/13/sc_inj-snapshot-2024-11-13T16:50:21-08:00.h5
# Running evaluate_impact_with_distgen...
# Setting distgen n_particle = 10000
# Setting impact timeout = 10000
# Setting impact header:Nx = 32
# Setting impact header:Ny = 32
# Setting impact header:Nz = 32
# Setting impact numprocs = 64
# Setting Npcol, Nprow = 8, 8
# Enabling MPI
# Setting impact command = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe
# Setting impact command_mpi = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# Setting impact mpi_run = salloc --partition milano --account ad:ard-online -N 1 -n {nproc} mpirun -n {nproc} {command_mpi}
# Setting impact stop = 14
# Removed element: stop_1
# Set stop to s = 14
# Setting distgen t_dist:sigma_t:value = 6.794055201698514
# Setting impact RFGUNB:rf_field_scale = 16486924.441374516
# Setting impact RFGUNB:autophase_deg = 0.0
# Setting impact SOL1B:solenoid_field_scale = 0.05137057221689382
# Setting impact SOL2B:solenoid_field_scale = 0.02902505616926497
# Setting distgen total_charge:value = 70.74709504
# Setting impact BUN1B:rf_field_scale = 1696986.06875
# Setting impact BUN1B:autophase_deg = -57.0
# Setting impact CAVL011:rf_field_scale = 12119176.690838391
# Setting impact CAVL012:rf_field_scale = 9322056.73142405
# Setting impact CAVL013:rf_field_scale = 20323607.85290211
# Setting impact CAVL014:rf_field_scale = 9322197.797961187
# Setting impact CAVL015:rf_field_scale = 22934136.52685117
# Setting impact CAVL016:rf_field_scale = 30951734.127665885
# Setting impact CAVL017:rf_field_scale = 30019202.252309866
# Setting impact CAVL018:rf_field_scale = 30951626.870286804
# Setting impact CAVL011:autophase_deg = -0.0014708149699890205
# Setting impact CAVL012:autophase_deg = 0.0007139393425699345
# Setting impact CAVL013:autophase_deg = -0.0008586584028462373
# Setting impact CAVL014:autophase_deg = -0.0011247003694426772
# Setting impact CAVL015:autophase_deg = -5.2963262371197306e-05
# Setting impact CAVL016:autophase_deg = -4.999400593137021
# Setting impact CAVL017:autophase_deg = -12.642351168071396
# Setting impact CAVL018:autophase_deg = 12.2510494810128
# Setting impact Q0H01:b1_gradient = 2.010210597008055
# Setting impact Q0H02:b1_gradient = -1.8159031249618547
# Setting impact Q0H03:b1_gradient = -0.790591701852188
# Setting impact Q0H04:b1_gradient = 1.5858007710121944
# Setting impact Q0H05:b1_gradient = 1.9303415590061956
# Setting impact Q0H06:b1_gradient = -0.5489386794309427
# Setting impact Q0H07:b1_gradient = -2.3054513096097997
# Setting impact Q0H08:b1_gradient = 2.4344025833775524
# Setting impact total_charge = 1
# Distribution format: None
#    Warning: no output file specified, defaulting to "None".
# Output file: None
#
# Creating beam distribution....
#    Beam starting from: cathode
#    Total charge: 70.7471 pC.
#    Number of macroparticles: 10000.
#    xy distribution: 2D File PDF
#       2D pdf file: //sdf/group/ad/sw/scm/repos/optics/lcls-lattice/distgen/models/sc_inj/vcc_image/laser_image.txt
#       min_x = -353.4 µm, max_x = 353.4 µm
#       min_y = -318.525 µm, max_y = 318.525 µm
#    t distribution: Gaussian
#       avg_t = 0 ps, sigma_t = 6.794 ps
#       Left n_sigma_cutoff = 3, Right n_sigma_cutoff = -3
#    px distribution: Gaussian
#       avg_px = 0 eV/c, sigma_px = 410.645 eV/c
#    py distribution: Gaussian
#       avg_py = 0 eV/c, sigma_py = 410.645 eV/c
#    pz distribution: Gaussian
#       avg_pz = 0 eV/c, sigma_pz = 410.645 eV/c
#    Shifting avg_x = 2.88034 µm -> 2.88034 µm
#    Shifting avg_y = 14.5416 µm -> 14.5416 µm
#    Shifting avg_px = -0.505043 eV/c -> 0 eV/c
#    Scaling sigma_px = 410.359 eV/c -> 410.645 eV/c
#    Shifting avg_py = -0.379762 eV/c -> 0 eV/c
#    Scaling sigma_py = 410.536 eV/c -> 410.645 eV/c
#    Shifting avg_pz = -0.592592 eV/c -> 0 eV/c
#    Scaling sigma_pz = 410.566 eV/c -> 410.645 eV/c
#    Shifting avg_t = -0.00501233 ps -> 0 ps
#    Scaling sigma_t = 6.70127 ps -> 6.70287 ps
#    Cathode start: fixing pz momenta to forward hemisphere
#       avg_pz -> 327.73 eV/c, sigma_pz -> 247.432 eV/c
# ...done. Time Elapsed: 200.863 ms.
#
#    Created particles in .particles:
#    ParticleGroup with 10000 particles with total charge 7.074709504000004e-11 C
# Autophase bookkeeper found settings, applying them
# Setting RFGUNB relative phase = 0.0 deg
# Found RFGUNB     relative phase = 0.00 deg
# Setting BUN1B relative phase = -57.0 deg
# Found BUN1B      relative phase = -57.00 deg
# Setting CAVL011 relative phase = -0.0014708149699890205 deg
# Found CAVL011    relative phase = -0.00 deg
# Setting CAVL012 relative phase = 0.0007139393425699345 deg
# Found CAVL012    relative phase = 0.00 deg
# Setting CAVL013 relative phase = -0.0008586584028462373 deg
# Found CAVL013    relative phase = -0.00 deg
# Setting CAVL014 relative phase = -0.0011247003694426772 deg
# Found CAVL014    relative phase = -0.00 deg
# Setting CAVL015 relative phase = -5.2963262371197306e-05 deg
# Found CAVL015    relative phase = -0.00 deg
# Setting CAVL016 relative phase = -4.999400593137021 deg
# Found CAVL016    relative phase = -5.00 deg
# Setting CAVL017 relative phase = -12.642351168071396 deg
# Found CAVL017    relative phase = -12.64 deg
# Setting CAVL018 relative phase = 12.2510494810128 deg
# Found CAVL018    relative phase = 12.25 deg
# Running Impact-T in /sdf/home/m/mokun/SCRATCH/tmpm1ws_zhi
# salloc --partition milano --account ad:ard-online -N 1 -n 64 mpirun -n 64 /sdf/home/m/mokun/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# writing 10000 particles to /sdf/home/m/mokun/SCRATCH/tmpm1ws_zhi/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 10000 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 4.050318246839861e-11 according to initial particles
# Cathode start: Replaced Tini with -2.0290544042254925e-11 according to initial particles
# Changing particle offset factor zmu2 to 0
# Setting total charge to 7.074709504000004e-11 C
# Loaded fort 18 : Time and energy
# Loaded fort 24 : RMS X information
# Loaded fort 25 : RMS Y information
# Loaded fort 26 : RMS Z information
# Loaded fort 27 : Max amplitude information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 32 : Covariance matrix of the beam distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loaded fort 70 : Slice information of the final distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles YAG01B fort.71
# Loaded write beam particles CM01BEG fort.72
# Loaded write beam particles BEAM0 fort.73
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted YAG01B to ParticleGroup
# Converted CM01BEG to ParticleGroup
# Converted BEAM0 to ParticleGroup
# Dashboard written: //sdf/home/m/mokun/lume-output/plot/2024/11/13/lume-impact-live-demo-s3df-sc_inj-2024-11-13T16:50:21-08:00-dashboard.png
# ...finished in 3.5 min
# Summary output written: //sdf/home/m/mokun/lume-output/summary/2024/11/13/lume-impact-live-demo-s3df-sc_inj-2024-11-13T16:50:21-08:00.json

# %%
if __name__ == '__main__':
    while True:
        try:
            result = run1()
            sleep(10)
        except Exception as e:
            logger.info(e)
            if (e.__class__.__name__ == 'Exception'):
                logger.info('Stopping the Program')
                break
            else:
                logger.info('Something BAD happened. Sleeping for 10 s ...')      
                sleep(10)
# Out:
# Acquired settings from EPICS at: 2024-11-13T16:53:54-08:00
# Waiting for good CAMR:LGUN:950:Image:ArrayData
# EPICS shapshot written: //sdf/home/m/mokun/lume-output/snapshot/2024/11/13/sc_inj-snapshot-2024-11-13T16:53:54-08:00.h5
# Running evaluate_impact_with_distgen...
# Setting distgen n_particle = 10000
# Setting impact timeout = 10000
# Setting impact header:Nx = 32
# Setting impact header:Ny = 32
# Setting impact header:Nz = 32
# Setting impact numprocs = 64
# Setting Npcol, Nprow = 8, 8
# Enabling MPI
# Setting impact command = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe
# Setting impact command_mpi = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# Setting impact mpi_run = salloc --partition milano --account ad:ard-online -N 1 -n {nproc} mpirun -n {nproc} {command_mpi}
# Setting impact stop = 14
# Removed element: stop_1
# Set stop to s = 14
# Setting distgen t_dist:sigma_t:value = 6.794055201698514
# Setting impact RFGUNB:rf_field_scale = 16486924.441374516
# Setting impact RFGUNB:autophase_deg = 0.0
# Setting impact SOL1B:solenoid_field_scale = 0.05137057221689382
# Setting impact SOL2B:solenoid_field_scale = 0.02902505616926497
# Setting distgen total_charge:value = 71.27698432
# Setting impact BUN1B:rf_field_scale = 1696986.06875
# Setting impact BUN1B:autophase_deg = -57.0
# Setting impact CAVL011:rf_field_scale = 12119178.182831652
# Setting impact CAVL012:rf_field_scale = 9322058.470728053
# Setting impact CAVL013:rf_field_scale = 20323607.777566
# Setting impact CAVL014:rf_field_scale = 9322200.244090028
# Setting impact CAVL015:rf_field_scale = 22934136.921271622
# Setting impact CAVL016:rf_field_scale = 30951735.293080375
# Setting impact CAVL017:rf_field_scale = 30019119.225292124
# Setting impact CAVL018:rf_field_scale = 30951613.49859499
# Setting impact CAVL011:autophase_deg = -0.0014622567887332405
# Setting impact CAVL012:autophase_deg = 0.0006748404741172345
# Setting impact CAVL013:autophase_deg = -0.0008582695713483576
# Setting impact CAVL014:autophase_deg = -0.0011535231545325153
# Setting impact CAVL015:autophase_deg = -4.913813234108666e-05
# Setting impact CAVL016:autophase_deg = -4.999400261663721
# Setting impact CAVL017:autophase_deg = -12.589390571045199
# Setting impact CAVL018:autophase_deg = 12.179071111614936
# Setting impact Q0H01:b1_gradient = 2.010234497614153
# Setting impact Q0H02:b1_gradient = -1.8160014981929153
# Setting impact Q0H03:b1_gradient = -0.790528582036834
# Setting impact Q0H04:b1_gradient = 1.5857970160641124
# Setting impact Q0H05:b1_gradient = 1.9300370328467182
# Setting impact Q0H06:b1_gradient = -0.5488795713556334
# Setting impact Q0H07:b1_gradient = -2.3054597737453424
# Setting impact Q0H08:b1_gradient = 2.434402032204896
# Setting impact total_charge = 1
# Distribution format: None
#    Warning: no output file specified, defaulting to "None".
# Output file: None
#
# Creating beam distribution....
#    Beam starting from: cathode
#    Total charge: 71.277 pC.
#    Number of macroparticles: 10000.
#    xy distribution: 2D File PDF
#       2D pdf file: //sdf/group/ad/sw/scm/repos/optics/lcls-lattice/distgen/models/sc_inj/vcc_image/laser_image.txt
#       min_x = -353.4 µm, max_x = 353.4 µm
#       min_y = -318.525 µm, max_y = 318.525 µm
#    t distribution: Gaussian
#       avg_t = 0 ps, sigma_t = 6.794 ps
#       Left n_sigma_cutoff = 3, Right n_sigma_cutoff = -3
#    px distribution: Gaussian
#       avg_px = 0 eV/c, sigma_px = 410.645 eV/c
#    py distribution: Gaussian
#       avg_py = 0 eV/c, sigma_py = 410.645 eV/c
#    pz distribution: Gaussian
#       avg_pz = 0 eV/c, sigma_pz = 410.645 eV/c
#    Shifting avg_x = 2.88034 µm -> 2.88034 µm
#    Shifting avg_y = 14.5416 µm -> 14.5416 µm
#    Shifting avg_px = -0.505043 eV/c -> 0 eV/c
#    Scaling sigma_px = 410.359 eV/c -> 410.645 eV/c
#    Shifting avg_py = -0.379762 eV/c -> 0 eV/c
#    Scaling sigma_py = 410.536 eV/c -> 410.645 eV/c
#    Shifting avg_pz = -0.592592 eV/c -> 0 eV/c
#    Scaling sigma_pz = 410.566 eV/c -> 410.645 eV/c
#    Shifting avg_t = -0.00501233 ps -> 0 ps
#    Scaling sigma_t = 6.70127 ps -> 6.70287 ps
#    Cathode start: fixing pz momenta to forward hemisphere
#       avg_pz -> 327.73 eV/c, sigma_pz -> 247.432 eV/c
# ...done. Time Elapsed: 144.271 ms.
#
#    Created particles in .particles:
#    ParticleGroup with 10000 particles with total charge 7.127698431999999e-11 C
# Autophase bookkeeper found settings, applying them
# Setting RFGUNB relative phase = 0.0 deg
# Found RFGUNB     relative phase = 0.00 deg
# Setting BUN1B relative phase = -57.0 deg
# Found BUN1B      relative phase = -57.00 deg
# Setting CAVL011 relative phase = -0.0014622567887332405 deg
# Found CAVL011    relative phase = -0.00 deg
# Setting CAVL012 relative phase = 0.0006748404741172345 deg
# Found CAVL012    relative phase = 0.00 deg
# Setting CAVL013 relative phase = -0.0008582695713483576 deg
# Found CAVL013    relative phase = -0.00 deg
# Setting CAVL014 relative phase = -0.0011535231545325153 deg
# Found CAVL014    relative phase = -0.00 deg
# Setting CAVL015 relative phase = -4.913813234108666e-05 deg
# Found CAVL015    relative phase = -0.00 deg
# Setting CAVL016 relative phase = -4.999400261663721 deg
# Found CAVL016    relative phase = -5.00 deg
# Setting CAVL017 relative phase = -12.589390571045199 deg
# Found CAVL017    relative phase = -12.59 deg
# Setting CAVL018 relative phase = 12.179071111614936 deg
# Found CAVL018    relative phase = 12.18 deg
# Running Impact-T in /sdf/home/m/mokun/SCRATCH/tmpsne_l2g1
# salloc --partition milano --account ad:ard-online -N 1 -n 64 mpirun -n 64 /sdf/home/m/mokun/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# writing 10000 particles to /sdf/home/m/mokun/SCRATCH/tmpsne_l2g1/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 10000 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 4.050318246839861e-11 according to initial particles
# Cathode start: Replaced Tini with -2.0290544042254925e-11 according to initial particles
# Changing particle offset factor zmu2 to 0
# Setting total charge to 7.127698431999999e-11 C
# Loaded fort 18 : Time and energy
# Loaded fort 24 : RMS X information
# Loaded fort 25 : RMS Y information
# Loaded fort 26 : RMS Z information
# Loaded fort 27 : Max amplitude information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 32 : Covariance matrix of the beam distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loaded fort 70 : Slice information of the final distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles YAG01B fort.71
# Loaded write beam particles CM01BEG fort.72
# Loaded write beam particles BEAM0 fort.73
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted YAG01B to ParticleGroup
# Converted CM01BEG to ParticleGroup
# Converted BEAM0 to ParticleGroup
# Dashboard written: //sdf/home/m/mokun/lume-output/plot/2024/11/13/lume-impact-live-demo-s3df-sc_inj-2024-11-13T16:53:54-08:00-dashboard.png
# ...finished in 2.8 min
# Summary output written: //sdf/home/m/mokun/lume-output/summary/2024/11/13/lume-impact-live-demo-s3df-sc_inj-2024-11-13T16:53:54-08:00.json
# Acquired settings from EPICS at: 2024-11-13T16:56:51-08:00
# Waiting for good CAMR:LGUN:950:Image:ArrayData
# EPICS shapshot written: //sdf/home/m/mokun/lume-output/snapshot/2024/11/13/sc_inj-snapshot-2024-11-13T16:56:51-08:00.h5
# Running evaluate_impact_with_distgen...
# Setting distgen n_particle = 10000
# Setting impact timeout = 10000
# Setting impact header:Nx = 32
# Setting impact header:Ny = 32
# Setting impact header:Nz = 32
# Setting impact numprocs = 64
# Setting Npcol, Nprow = 8, 8
# Enabling MPI
# Setting impact command = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe
# Setting impact command_mpi = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# Setting impact mpi_run = salloc --partition milano --account ad:ard-online -N 1 -n {nproc} mpirun -n {nproc} {command_mpi}
# Setting impact stop = 14
# Removed element: stop_1
# Set stop to s = 14
# Setting distgen t_dist:sigma_t:value = 6.794055201698514
# Setting impact RFGUNB:rf_field_scale = 16486924.441374516
# Setting impact RFGUNB:autophase_deg = 0.0
# Setting impact SOL1B:solenoid_field_scale = 0.05137057221689382
# Setting impact SOL2B:solenoid_field_scale = 0.02902505616926497
# Setting distgen total_charge:value = 71.3077248
# Setting impact BUN1B:rf_field_scale = 1696986.06875
# Setting impact BUN1B:autophase_deg = -57.0
# Setting impact CAVL011:rf_field_scale = 12119176.822972316
# Setting impact CAVL012:rf_field_scale = 9322054.498652358
# Setting impact CAVL013:rf_field_scale = 20323607.070463132
# Setting impact CAVL014:rf_field_scale = 9322200.914673837
# Setting impact CAVL015:rf_field_scale = 22934133.90956006
# Setting impact CAVL016:rf_field_scale = 30951735.30640618
# Setting impact CAVL017:rf_field_scale = 30019139.79979347
# Setting impact CAVL018:rf_field_scale = 30951616.829929218
# Setting impact CAVL011:autophase_deg = -0.001467739710611815
# Setting impact CAVL012:autophase_deg = 0.0007154870454684006
# Setting impact CAVL013:autophase_deg = -0.0008561611054566758
# Setting impact CAVL014:autophase_deg = -0.001141463321419317
# Setting impact CAVL015:autophase_deg = -5.364467052773603e-05
# Setting impact CAVL016:autophase_deg = -4.999399970059306
# Setting impact CAVL017:autophase_deg = -12.582244446300411
# Setting impact CAVL018:autophase_deg = 12.189541086106797
# Setting impact Q0H01:b1_gradient = 2.0100421680536606
# Setting impact Q0H02:b1_gradient = -1.8159523554351935
# Setting impact Q0H03:b1_gradient = -0.7905210578374869
# Setting impact Q0H04:b1_gradient = 1.5858503390488197
# Setting impact Q0H05:b1_gradient = 1.929688934892013
# Setting impact Q0H06:b1_gradient = -0.5488564524209981
# Setting impact Q0H07:b1_gradient = -2.305451057659074
# Setting impact Q0H08:b1_gradient = 2.434401554270191
# Setting impact total_charge = 1
# Distribution format: None
#    Warning: no output file specified, defaulting to "None".
# Output file: None
#
# Creating beam distribution....
#    Beam starting from: cathode
#    Total charge: 71.3077 pC.
#    Number of macroparticles: 10000.
#    xy distribution: 2D File PDF
#       2D pdf file: //sdf/group/ad/sw/scm/repos/optics/lcls-lattice/distgen/models/sc_inj/vcc_image/laser_image.txt
#       min_x = -353.4 µm, max_x = 353.4 µm
#       min_y = -318.525 µm, max_y = 318.525 µm
#    t distribution: Gaussian
#       avg_t = 0 ps, sigma_t = 6.794 ps
#       Left n_sigma_cutoff = 3, Right n_sigma_cutoff = -3
#    px distribution: Gaussian
#       avg_px = 0 eV/c, sigma_px = 410.645 eV/c
#    py distribution: Gaussian
#       avg_py = 0 eV/c, sigma_py = 410.645 eV/c
#    pz distribution: Gaussian
#       avg_pz = 0 eV/c, sigma_pz = 410.645 eV/c
#    Shifting avg_x = 2.88034 µm -> 2.88034 µm
#    Shifting avg_y = 14.5416 µm -> 14.5416 µm
#    Shifting avg_px = -0.505043 eV/c -> 0 eV/c
#    Scaling sigma_px = 410.359 eV/c -> 410.645 eV/c
#    Shifting avg_py = -0.379762 eV/c -> 0 eV/c
#    Scaling sigma_py = 410.536 eV/c -> 410.645 eV/c
#    Shifting avg_pz = -0.592592 eV/c -> 0 eV/c
#    Scaling sigma_pz = 410.566 eV/c -> 410.645 eV/c
#    Shifting avg_t = -0.00501233 ps -> 0 ps
#    Scaling sigma_t = 6.70127 ps -> 6.70287 ps
#    Cathode start: fixing pz momenta to forward hemisphere
#       avg_pz -> 327.73 eV/c, sigma_pz -> 247.432 eV/c
# ...done. Time Elapsed: 182.796 ms.
#
#    Created particles in .particles:
#    ParticleGroup with 10000 particles with total charge 7.130772480000002e-11 C
# Autophase bookkeeper found settings, applying them
# Setting RFGUNB relative phase = 0.0 deg
# Found RFGUNB     relative phase = 0.00 deg
# Setting BUN1B relative phase = -57.0 deg
# Found BUN1B      relative phase = -57.00 deg
# Setting CAVL011 relative phase = -0.001467739710611815 deg
# Found CAVL011    relative phase = -0.00 deg
# Setting CAVL012 relative phase = 0.0007154870454684006 deg
# Found CAVL012    relative phase = 0.00 deg
# Setting CAVL013 relative phase = -0.0008561611054566758 deg
# Found CAVL013    relative phase = -0.00 deg
# Setting CAVL014 relative phase = -0.001141463321419317 deg
# Found CAVL014    relative phase = -0.00 deg
# Setting CAVL015 relative phase = -5.364467052773603e-05 deg
# Found CAVL015    relative phase = -0.00 deg
# Setting CAVL016 relative phase = -4.999399970059306 deg
# Found CAVL016    relative phase = -5.00 deg
# Setting CAVL017 relative phase = -12.582244446300411 deg
# Found CAVL017    relative phase = -12.58 deg
# Setting CAVL018 relative phase = 12.189541086106797 deg
# Found CAVL018    relative phase = 12.19 deg
# Running Impact-T in /sdf/home/m/mokun/SCRATCH/tmp3yf7xjiv
# salloc --partition milano --account ad:ard-online -N 1 -n 64 mpirun -n 64 /sdf/home/m/mokun/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# writing 10000 particles to /sdf/home/m/mokun/SCRATCH/tmp3yf7xjiv/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 10000 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 4.050318246839861e-11 according to initial particles
# Cathode start: Replaced Tini with -2.0290544042254925e-11 according to initial particles
# Changing particle offset factor zmu2 to 0
# Setting total charge to 7.130772480000002e-11 C
# Loaded fort 18 : Time and energy
# Loaded fort 24 : RMS X information
# Loaded fort 25 : RMS Y information
# Loaded fort 26 : RMS Z information
# Loaded fort 27 : Max amplitude information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 32 : Covariance matrix of the beam distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loaded fort 70 : Slice information of the final distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles YAG01B fort.71
# Loaded write beam particles CM01BEG fort.72
# Loaded write beam particles BEAM0 fort.73
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted YAG01B to ParticleGroup
# Converted CM01BEG to ParticleGroup
# Converted BEAM0 to ParticleGroup
# Dashboard written: //sdf/home/m/mokun/lume-output/plot/2024/11/13/lume-impact-live-demo-s3df-sc_inj-2024-11-13T16:56:51-08:00-dashboard.png
# ...finished in 2.8 min
# Summary output written: //sdf/home/m/mokun/lume-output/summary/2024/11/13/lume-impact-live-demo-s3df-sc_inj-2024-11-13T16:56:51-08:00.json
# Acquired settings from EPICS at: 2024-11-13T16:59:49-08:00
# Waiting for good CAMR:LGUN:950:Image:ArrayData
# EPICS shapshot written: //sdf/home/m/mokun/lume-output/snapshot/2024/11/13/sc_inj-snapshot-2024-11-13T16:59:49-08:00.h5
# Running evaluate_impact_with_distgen...
# Setting distgen n_particle = 10000
# Setting impact timeout = 10000
# Setting impact header:Nx = 32
# Setting impact header:Ny = 32
# Setting impact header:Nz = 32
# Setting impact numprocs = 64
# Setting Npcol, Nprow = 8, 8
# Enabling MPI
# Setting impact command = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe
# Setting impact command_mpi = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# Setting impact mpi_run = salloc --partition milano --account ad:ard-online -N 1 -n {nproc} mpirun -n {nproc} {command_mpi}
# Setting impact stop = 14
# Removed element: stop_1
# Set stop to s = 14
# Setting distgen t_dist:sigma_t:value = 6.794055201698514
# Setting impact RFGUNB:rf_field_scale = 16486924.441374516
# Setting impact RFGUNB:autophase_deg = 0.0
# Setting impact SOL1B:solenoid_field_scale = 0.05137057221689382
# Setting impact SOL2B:solenoid_field_scale = 0.02902505616926497
# Setting distgen total_charge:value = 71.80739072
# Setting impact BUN1B:rf_field_scale = 1696986.06875
# Setting impact BUN1B:autophase_deg = -57.0
# Setting impact CAVL011:rf_field_scale = 12119176.23749085
# Setting impact CAVL012:rf_field_scale = 9322057.916350106
# Setting impact CAVL013:rf_field_scale = 20323607.579955127
# Setting impact CAVL014:rf_field_scale = 9322199.803621681
# Setting impact CAVL015:rf_field_scale = 22934135.42291345
# Setting impact CAVL016:rf_field_scale = 30951734.189175807
# Setting impact CAVL017:rf_field_scale = 30019117.28288141
# Setting impact CAVL018:rf_field_scale = 30951594.42671697
# Setting impact CAVL011:autophase_deg = -0.0014589802175735966
# Setting impact CAVL012:autophase_deg = 0.0007160829830125878
# Setting impact CAVL013:autophase_deg = -0.0008538617042408488
# Setting impact CAVL014:autophase_deg = -0.0011344048725120681
# Setting impact CAVL015:autophase_deg = -5.279029002844271e-05
# Setting impact CAVL016:autophase_deg = -4.999401850979742
# Setting impact CAVL017:autophase_deg = -12.521957939229843
# Setting impact CAVL018:autophase_deg = 12.153620479013655
# Setting impact Q0H01:b1_gradient = 2.010079588594862
# Setting impact Q0H02:b1_gradient = -1.8159727779995773
# Setting impact Q0H03:b1_gradient = -0.7905319399136823
# Setting impact Q0H04:b1_gradient = 1.5857174668320848
# Setting impact Q0H05:b1_gradient = 1.9299214881816178
# Setting impact Q0H06:b1_gradient = -0.5489942527216007
# Setting impact Q0H07:b1_gradient = -2.3054496159499123
# Setting impact Q0H08:b1_gradient = 2.4344092193322022
# Setting impact total_charge = 1
# Distribution format: None
#    Warning: no output file specified, defaulting to "None".
# Output file: None
#
# Creating beam distribution....
#    Beam starting from: cathode
#    Total charge: 71.8074 pC.
#    Number of macroparticles: 10000.
#    xy distribution: 2D File PDF
#       2D pdf file: //sdf/group/ad/sw/scm/repos/optics/lcls-lattice/distgen/models/sc_inj/vcc_image/laser_image.txt
#       min_x = -353.4 µm, max_x = 353.4 µm
#       min_y = -318.525 µm, max_y = 318.525 µm
#    t distribution: Gaussian
#       avg_t = 0 ps, sigma_t = 6.794 ps
#       Left n_sigma_cutoff = 3, Right n_sigma_cutoff = -3
#    px distribution: Gaussian
#       avg_px = 0 eV/c, sigma_px = 410.645 eV/c
#    py distribution: Gaussian
#       avg_py = 0 eV/c, sigma_py = 410.645 eV/c
#    pz distribution: Gaussian
#       avg_pz = 0 eV/c, sigma_pz = 410.645 eV/c
#    Shifting avg_x = 2.88034 µm -> 2.88034 µm
#    Shifting avg_y = 14.5416 µm -> 14.5416 µm
#    Shifting avg_px = -0.505043 eV/c -> 0 eV/c
#    Scaling sigma_px = 410.359 eV/c -> 410.645 eV/c
#    Shifting avg_py = -0.379762 eV/c -> 0 eV/c
#    Scaling sigma_py = 410.536 eV/c -> 410.645 eV/c
#    Shifting avg_pz = -0.592592 eV/c -> 0 eV/c
#    Scaling sigma_pz = 410.566 eV/c -> 410.645 eV/c
#    Shifting avg_t = -0.00501233 ps -> 0 ps
#    Scaling sigma_t = 6.70127 ps -> 6.70287 ps
#    Cathode start: fixing pz momenta to forward hemisphere
#       avg_pz -> 327.73 eV/c, sigma_pz -> 247.432 eV/c
# ...done. Time Elapsed: 421.185 ms.
#
#    Created particles in .particles:
#    ParticleGroup with 10000 particles with total charge 7.180739072000003e-11 C
# Autophase bookkeeper found settings, applying them
# Setting RFGUNB relative phase = 0.0 deg
# Found RFGUNB     relative phase = 0.00 deg
# Setting BUN1B relative phase = -57.0 deg
# Found BUN1B      relative phase = -57.00 deg
# Setting CAVL011 relative phase = -0.0014589802175735966 deg
# Found CAVL011    relative phase = -0.00 deg
# Setting CAVL012 relative phase = 0.0007160829830125878 deg
# Found CAVL012    relative phase = 0.00 deg
# Setting CAVL013 relative phase = -0.0008538617042408488 deg
# Found CAVL013    relative phase = -0.00 deg
# Setting CAVL014 relative phase = -0.0011344048725120681 deg
# Found CAVL014    relative phase = -0.00 deg
# Setting CAVL015 relative phase = -5.279029002844271e-05 deg
# Found CAVL015    relative phase = -0.00 deg
# Setting CAVL016 relative phase = -4.999401850979742 deg
# Found CAVL016    relative phase = -5.00 deg
# Setting CAVL017 relative phase = -12.521957939229843 deg
# Found CAVL017    relative phase = -12.52 deg
# Setting CAVL018 relative phase = 12.153620479013655 deg
# Found CAVL018    relative phase = 12.15 deg
# Running Impact-T in /sdf/home/m/mokun/SCRATCH/tmp5yiyo5hw
# salloc --partition milano --account ad:ard-online -N 1 -n 64 mpirun -n 64 /sdf/home/m/mokun/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# writing 10000 particles to /sdf/home/m/mokun/SCRATCH/tmp5yiyo5hw/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 10000 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 4.050318246839861e-11 according to initial particles
# Cathode start: Replaced Tini with -2.0290544042254925e-11 according to initial particles
# Changing particle offset factor zmu2 to 0
# Setting total charge to 7.180739072000003e-11 C
# Loaded fort 18 : Time and energy
# Loaded fort 24 : RMS X information
# Loaded fort 25 : RMS Y information
# Loaded fort 26 : RMS Z information
# Loaded fort 27 : Max amplitude information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 32 : Covariance matrix of the beam distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loaded fort 70 : Slice information of the final distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles YAG01B fort.71
# Loaded write beam particles CM01BEG fort.72
# Loaded write beam particles BEAM0 fort.73
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted YAG01B to ParticleGroup
# Converted CM01BEG to ParticleGroup
# Converted BEAM0 to ParticleGroup
# Dashboard written: //sdf/home/m/mokun/lume-output/plot/2024/11/13/lume-impact-live-demo-s3df-sc_inj-2024-11-13T16:59:49-08:00-dashboard.png
# ...finished in 2.8 min
# Summary output written: //sdf/home/m/mokun/lume-output/summary/2024/11/13/lume-impact-live-demo-s3df-sc_inj-2024-11-13T16:59:49-08:00.json
# Acquired settings from EPICS at: 2024-11-13T17:02:46-08:00
# Waiting for good CAMR:LGUN:950:Image:ArrayData
# EPICS shapshot written: //sdf/home/m/mokun/lume-output/snapshot/2024/11/13/sc_inj-snapshot-2024-11-13T17:02:46-08:00.h5
# Running evaluate_impact_with_distgen...
# Setting distgen n_particle = 10000
# Setting impact timeout = 10000
# Setting impact header:Nx = 32
# Setting impact header:Ny = 32
# Setting impact header:Nz = 32
# Setting impact numprocs = 64
# Setting Npcol, Nprow = 8, 8
# Enabling MPI
# Setting impact command = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe
# Setting impact command_mpi = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# Setting impact mpi_run = salloc --partition milano --account ad:ard-online -N 1 -n {nproc} mpirun -n {nproc} {command_mpi}
# Setting impact stop = 14
# Removed element: stop_1
# Set stop to s = 14
# Setting distgen t_dist:sigma_t:value = 6.794055201698514
# Setting impact RFGUNB:rf_field_scale = 16486924.441374516
# Setting impact RFGUNB:autophase_deg = 0.0
# Setting impact SOL1B:solenoid_field_scale = 0.05137057221689382
# Setting impact SOL2B:solenoid_field_scale = 0.02902505616926497
# Setting distgen total_charge:value = 73.68329728
# Setting impact BUN1B:rf_field_scale = 1696986.06875
# Setting impact BUN1B:autophase_deg = -57.0
# Setting impact CAVL011:rf_field_scale = 12119177.748966996
# Setting impact CAVL012:rf_field_scale = 9322055.76365367
# Setting impact CAVL013:rf_field_scale = 20323606.923551567
# Setting impact CAVL014:rf_field_scale = 9322199.51991739
# Setting impact CAVL015:rf_field_scale = 22934136.294149473
# Setting impact CAVL016:rf_field_scale = 30951733.651145883
# Setting impact CAVL017:rf_field_scale = 30019117.60126178
# Setting impact CAVL018:rf_field_scale = 30951673.270732716
# Setting impact CAVL011:autophase_deg = -0.0014733038196078907
# Setting impact CAVL012:autophase_deg = 0.0007195208385387952
# Setting impact CAVL013:autophase_deg = -0.0008538629735867654
# Setting impact CAVL014:autophase_deg = -0.001135383838862164
# Setting impact CAVL015:autophase_deg = -5.119631719796569e-05
# Setting impact CAVL016:autophase_deg = -4.999401473034774
# Setting impact CAVL017:autophase_deg = -12.416107606852947
# Setting impact CAVL018:autophase_deg = 12.023396960127512
# Setting impact Q0H01:b1_gradient = 2.010312421539294
# Setting impact Q0H02:b1_gradient = -1.8159201231574684
# Setting impact Q0H03:b1_gradient = -0.7906117390610408
# Setting impact Q0H04:b1_gradient = 1.5858578138863801
# Setting impact Q0H05:b1_gradient = 1.930332502569695
# Setting impact Q0H06:b1_gradient = -0.5488071742878962
# Setting impact Q0H07:b1_gradient = -2.3054458844932597
# Setting impact Q0H08:b1_gradient = 2.4344062050151716
# Setting impact total_charge = 1
# Distribution format: None
#    Warning: no output file specified, defaulting to "None".
# Output file: None
#
# Creating beam distribution....
#    Beam starting from: cathode
#    Total charge: 73.6833 pC.
#    Number of macroparticles: 10000.
#    xy distribution: 2D File PDF
#       2D pdf file: //sdf/group/ad/sw/scm/repos/optics/lcls-lattice/distgen/models/sc_inj/vcc_image/laser_image.txt
#       min_x = -353.4 µm, max_x = 353.4 µm
#       min_y = -318.525 µm, max_y = 318.525 µm
#    t distribution: Gaussian
#       avg_t = 0 ps, sigma_t = 6.794 ps
#       Left n_sigma_cutoff = 3, Right n_sigma_cutoff = -3
#    px distribution: Gaussian
#       avg_px = 0 eV/c, sigma_px = 410.645 eV/c
#    py distribution: Gaussian
#       avg_py = 0 eV/c, sigma_py = 410.645 eV/c
#    pz distribution: Gaussian
#       avg_pz = 0 eV/c, sigma_pz = 410.645 eV/c
#    Shifting avg_x = 2.88034 µm -> 2.88034 µm
#    Shifting avg_y = 14.5416 µm -> 14.5416 µm
#    Shifting avg_px = -0.505043 eV/c -> 0 eV/c
#    Scaling sigma_px = 410.359 eV/c -> 410.645 eV/c
#    Shifting avg_py = -0.379762 eV/c -> 0 eV/c
#    Scaling sigma_py = 410.536 eV/c -> 410.645 eV/c
#    Shifting avg_pz = -0.592592 eV/c -> 0 eV/c
#    Scaling sigma_pz = 410.566 eV/c -> 410.645 eV/c
#    Shifting avg_t = -0.00501233 ps -> 0 ps
#    Scaling sigma_t = 6.70127 ps -> 6.70287 ps
#    Cathode start: fixing pz momenta to forward hemisphere
#       avg_pz -> 327.73 eV/c, sigma_pz -> 247.432 eV/c
# ...done. Time Elapsed: 253.192 ms.
#
#    Created particles in .particles:
#    ParticleGroup with 10000 particles with total charge 7.368329728e-11 C
# Autophase bookkeeper found settings, applying them
# Setting RFGUNB relative phase = 0.0 deg
# Found RFGUNB     relative phase = 0.00 deg
# Setting BUN1B relative phase = -57.0 deg
# Found BUN1B      relative phase = -57.00 deg
# Setting CAVL011 relative phase = -0.0014733038196078907 deg
# Found CAVL011    relative phase = -0.00 deg
# Setting CAVL012 relative phase = 0.0007195208385387952 deg
# Found CAVL012    relative phase = 0.00 deg
# Setting CAVL013 relative phase = -0.0008538629735867654 deg
# Found CAVL013    relative phase = -0.00 deg
# Setting CAVL014 relative phase = -0.001135383838862164 deg
# Found CAVL014    relative phase = -0.00 deg
# Setting CAVL015 relative phase = -5.119631719796569e-05 deg
# Found CAVL015    relative phase = -0.00 deg
# Setting CAVL016 relative phase = -4.999401473034774 deg
# Found CAVL016    relative phase = -5.00 deg
# Setting CAVL017 relative phase = -12.416107606852947 deg
# Found CAVL017    relative phase = -12.42 deg
# Setting CAVL018 relative phase = 12.023396960127512 deg
# Found CAVL018    relative phase = 12.02 deg
# Running Impact-T in /sdf/home/m/mokun/SCRATCH/tmp149u065o
# salloc --partition milano --account ad:ard-online -N 1 -n 64 mpirun -n 64 /sdf/home/m/mokun/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# writing 10000 particles to /sdf/home/m/mokun/SCRATCH/tmp149u065o/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 10000 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 4.050318246839861e-11 according to initial particles
# Cathode start: Replaced Tini with -2.0290544042254925e-11 according to initial particles
# Changing particle offset factor zmu2 to 0
# Setting total charge to 7.368329728e-11 C
# Loaded fort 18 : Time and energy
# Loaded fort 24 : RMS X information
# Loaded fort 25 : RMS Y information
# Loaded fort 26 : RMS Z information
# Loaded fort 27 : Max amplitude information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 32 : Covariance matrix of the beam distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loaded fort 70 : Slice information of the final distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles YAG01B fort.71
# Loaded write beam particles CM01BEG fort.72
# Loaded write beam particles BEAM0 fort.73
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted YAG01B to ParticleGroup
# Converted CM01BEG to ParticleGroup
# Converted BEAM0 to ParticleGroup
# Dashboard written: //sdf/home/m/mokun/lume-output/plot/2024/11/13/lume-impact-live-demo-s3df-sc_inj-2024-11-13T17:02:46-08:00-dashboard.png
# ...finished in 3.0 min
# Summary output written: //sdf/home/m/mokun/lume-output/summary/2024/11/13/lume-impact-live-demo-s3df-sc_inj-2024-11-13T17:02:46-08:00.json
# Acquired settings from EPICS at: 2024-11-13T17:05:55-08:00
# Waiting for good CAMR:LGUN:950:Image:ArrayData
# EPICS shapshot written: //sdf/home/m/mokun/lume-output/snapshot/2024/11/13/sc_inj-snapshot-2024-11-13T17:05:55-08:00.h5
# Running evaluate_impact_with_distgen...
# Setting distgen n_particle = 10000
# Setting impact timeout = 10000
# Setting impact header:Nx = 32
# Setting impact header:Ny = 32
# Setting impact header:Nz = 32
# Setting impact numprocs = 64
# Setting Npcol, Nprow = 8, 8
# Enabling MPI
# Setting impact command = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe
# Setting impact command_mpi = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# Setting impact mpi_run = salloc --partition milano --account ad:ard-online -N 1 -n {nproc} mpirun -n {nproc} {command_mpi}
# Setting impact stop = 14
# Removed element: stop_1
# Set stop to s = 14
# Setting distgen t_dist:sigma_t:value = 6.794055201698514
# Setting impact RFGUNB:rf_field_scale = 16486924.441374516
# Setting impact RFGUNB:autophase_deg = 0.0
# Setting impact SOL1B:solenoid_field_scale = 0.05137057221689382
# Setting impact SOL2B:solenoid_field_scale = 0.029023309941346363
# Setting distgen total_charge:value = 71.1432192
# Setting impact BUN1B:rf_field_scale = 1696986.06875
# Setting impact BUN1B:autophase_deg = -57.0
# Setting impact CAVL011:rf_field_scale = 12119176.367590493
# Setting impact CAVL012:rf_field_scale = 9322052.352321094
# Setting impact CAVL013:rf_field_scale = 20323606.64434528
# Setting impact CAVL014:rf_field_scale = 9322200.206728226
# Setting impact CAVL015:rf_field_scale = 22934137.18130653
# Setting impact CAVL016:rf_field_scale = 30951733.15999771
# Setting impact CAVL017:rf_field_scale = 30019131.96201405
# Setting impact CAVL018:rf_field_scale = 30951652.02430401
# Setting impact CAVL011:autophase_deg = -0.001463203809879493
# Setting impact CAVL012:autophase_deg = 0.0007061350694958987
# Setting impact CAVL013:autophase_deg = -0.0008576588702304041
# Setting impact CAVL014:autophase_deg = -0.0011347338340462199
# Setting impact CAVL015:autophase_deg = -4.939186044605748e-05
# Setting impact CAVL016:autophase_deg = -4.9993948613717505
# Setting impact CAVL017:autophase_deg = -12.506239284446085
# Setting impact CAVL018:autophase_deg = 12.121418141936779
# Setting impact Q0H01:b1_gradient = 2.010183011243842
# Setting impact Q0H02:b1_gradient = -1.8160283215561408
# Setting impact Q0H03:b1_gradient = -0.7905564540169416
# Setting impact Q0H04:b1_gradient = 1.5859046575925324
# Setting impact Q0H05:b1_gradient = 1.930046594004652
# Setting impact Q0H06:b1_gradient = -0.5489201085174278
# Setting impact Q0H07:b1_gradient = -2.3054436592163503
# Setting impact Q0H08:b1_gradient = 2.4343968019800197
# Setting impact total_charge = 1
# Distribution format: None
#    Warning: no output file specified, defaulting to "None".
# Output file: None
#
# Creating beam distribution....
#    Beam starting from: cathode
#    Total charge: 71.1432 pC.
#    Number of macroparticles: 10000.
#    xy distribution: 2D File PDF
#       2D pdf file: //sdf/group/ad/sw/scm/repos/optics/lcls-lattice/distgen/models/sc_inj/vcc_image/laser_image.txt
#       min_x = -353.4 µm, max_x = 353.4 µm
#       min_y = -318.525 µm, max_y = 318.525 µm
#    t distribution: Gaussian
#       avg_t = 0 ps, sigma_t = 6.794 ps
#       Left n_sigma_cutoff = 3, Right n_sigma_cutoff = -3
#    px distribution: Gaussian
#       avg_px = 0 eV/c, sigma_px = 410.645 eV/c
#    py distribution: Gaussian
#       avg_py = 0 eV/c, sigma_py = 410.645 eV/c
#    pz distribution: Gaussian
#       avg_pz = 0 eV/c, sigma_pz = 410.645 eV/c
#    Shifting avg_x = 2.88034 µm -> 2.88034 µm
#    Shifting avg_y = 14.5416 µm -> 14.5416 µm
#    Shifting avg_px = -0.505043 eV/c -> 0 eV/c
#    Scaling sigma_px = 410.359 eV/c -> 410.645 eV/c
#    Shifting avg_py = -0.379762 eV/c -> 0 eV/c
#    Scaling sigma_py = 410.536 eV/c -> 410.645 eV/c
#    Shifting avg_pz = -0.592592 eV/c -> 0 eV/c
#    Scaling sigma_pz = 410.566 eV/c -> 410.645 eV/c
#    Shifting avg_t = -0.00501233 ps -> 0 ps
#    Scaling sigma_t = 6.70127 ps -> 6.70287 ps
#    Cathode start: fixing pz momenta to forward hemisphere
#       avg_pz -> 327.73 eV/c, sigma_pz -> 247.432 eV/c
# ...done. Time Elapsed: 297.992 ms.
#
#    Created particles in .particles:
#    ParticleGroup with 10000 particles with total charge 7.11432192e-11 C
# Autophase bookkeeper found settings, applying them
# Setting RFGUNB relative phase = 0.0 deg
# Found RFGUNB     relative phase = 0.00 deg
# Setting BUN1B relative phase = -57.0 deg
# Found BUN1B      relative phase = -57.00 deg
# Setting CAVL011 relative phase = -0.001463203809879493 deg
# Found CAVL011    relative phase = -0.00 deg
# Setting CAVL012 relative phase = 0.0007061350694958987 deg
# Found CAVL012    relative phase = 0.00 deg
# Setting CAVL013 relative phase = -0.0008576588702304041 deg
# Found CAVL013    relative phase = -0.00 deg
# Setting CAVL014 relative phase = -0.0011347338340462199 deg
# Found CAVL014    relative phase = -0.00 deg
# Setting CAVL015 relative phase = -4.939186044605748e-05 deg
# Found CAVL015    relative phase = -0.00 deg
# Setting CAVL016 relative phase = -4.9993948613717505 deg
# Found CAVL016    relative phase = -5.00 deg
# Setting CAVL017 relative phase = -12.506239284446085 deg
# Found CAVL017    relative phase = -12.51 deg
# Setting CAVL018 relative phase = 12.121418141936779 deg
# Found CAVL018    relative phase = 12.12 deg
# Running Impact-T in /sdf/home/m/mokun/SCRATCH/tmpap1nmlr2
# salloc --partition milano --account ad:ard-online -N 1 -n 64 mpirun -n 64 /sdf/home/m/mokun/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# writing 10000 particles to /sdf/home/m/mokun/SCRATCH/tmpap1nmlr2/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 10000 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 4.050318246839861e-11 according to initial particles
# Cathode start: Replaced Tini with -2.0290544042254925e-11 according to initial particles
# Changing particle offset factor zmu2 to 0
# Setting total charge to 7.11432192e-11 C
# Loaded fort 18 : Time and energy
# Loaded fort 24 : RMS X information
# Loaded fort 25 : RMS Y information
# Loaded fort 26 : RMS Z information
# Loaded fort 27 : Max amplitude information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 32 : Covariance matrix of the beam distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loaded fort 70 : Slice information of the final distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles YAG01B fort.71
# Loaded write beam particles CM01BEG fort.72
# Loaded write beam particles BEAM0 fort.73
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted YAG01B to ParticleGroup
# Converted CM01BEG to ParticleGroup
# Converted BEAM0 to ParticleGroup
# Dashboard written: //sdf/home/m/mokun/lume-output/plot/2024/11/13/lume-impact-live-demo-s3df-sc_inj-2024-11-13T17:05:55-08:00-dashboard.png
# ...finished in 3.0 min
# Summary output written: //sdf/home/m/mokun/lume-output/summary/2024/11/13/lume-impact-live-demo-s3df-sc_inj-2024-11-13T17:05:55-08:00.json
# Acquired settings from EPICS at: 2024-11-13T17:09:06-08:00
# Waiting for good CAMR:LGUN:950:Image:ArrayData
# EPICS shapshot written: //sdf/home/m/mokun/lume-output/snapshot/2024/11/13/sc_inj-snapshot-2024-11-13T17:09:06-08:00.h5
# Running evaluate_impact_with_distgen...
# Setting distgen n_particle = 10000
# Setting impact timeout = 10000
# Setting impact header:Nx = 32
# Setting impact header:Ny = 32
# Setting impact header:Nz = 32
# Setting impact numprocs = 64
# Setting Npcol, Nprow = 8, 8
# Enabling MPI
# Setting impact command = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe
# Setting impact command_mpi = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# Setting impact mpi_run = salloc --partition milano --account ad:ard-online -N 1 -n {nproc} mpirun -n {nproc} {command_mpi}
# Setting impact stop = 14
# Removed element: stop_1
# Set stop to s = 14
# Setting distgen t_dist:sigma_t:value = 6.794055201698514
# Setting impact RFGUNB:rf_field_scale = 16486924.441374516
# Setting impact RFGUNB:autophase_deg = 0.0
# Setting impact SOL1B:solenoid_field_scale = 0.05137057221689382
# Setting impact SOL2B:solenoid_field_scale = 0.029023309941346363
# Setting distgen total_charge:value = 73.99763968
# Setting impact BUN1B:rf_field_scale = 1696986.06875
# Setting impact BUN1B:autophase_deg = -57.0
# Setting impact CAVL011:rf_field_scale = 12119175.539191237
# Setting impact CAVL012:rf_field_scale = 9322052.018096209
# Setting impact CAVL013:rf_field_scale = 20323607.955818113
# Setting impact CAVL014:rf_field_scale = 9322199.883228121
# Setting impact CAVL015:rf_field_scale = 22934135.316381957
# Setting impact CAVL016:rf_field_scale = 30951733.423895154
# Setting impact CAVL017:rf_field_scale = 30019125.043972235
# Setting impact CAVL018:rf_field_scale = 30951672.094270535
# Setting impact CAVL011:autophase_deg = -0.0014556840340716748
# Setting impact CAVL012:autophase_deg = 0.0007059963906660277
# Setting impact CAVL013:autophase_deg = -0.0008521047550363557
# Setting impact CAVL014:autophase_deg = -0.0011352766350185006
# Setting impact CAVL015:autophase_deg = -4.981843429976984e-05
# Setting impact CAVL016:autophase_deg = -4.999397766240162
# Setting impact CAVL017:autophase_deg = -12.400008096841498
# Setting impact CAVL018:autophase_deg = 12.021884928172042
# Setting impact Q0H01:b1_gradient = 2.0101737342558987
# Setting impact Q0H02:b1_gradient = -1.8160210860959314
# Setting impact Q0H03:b1_gradient = -0.7906155878765524
# Setting impact Q0H04:b1_gradient = 1.5856947301165325
# Setting impact Q0H05:b1_gradient = 1.9303588713571973
# Setting impact Q0H06:b1_gradient = -0.5490475127082963
# Setting impact Q0H07:b1_gradient = -2.30543724554899
# Setting impact Q0H08:b1_gradient = 2.434398061291435
# Setting impact total_charge = 1
# Distribution format: None
#    Warning: no output file specified, defaulting to "None".
# Output file: None
#
# Creating beam distribution....
#    Beam starting from: cathode
#    Total charge: 73.9976 pC.
#    Number of macroparticles: 10000.
#    xy distribution: 2D File PDF
#       2D pdf file: //sdf/group/ad/sw/scm/repos/optics/lcls-lattice/distgen/models/sc_inj/vcc_image/laser_image.txt
#       min_x = -353.4 µm, max_x = 353.4 µm
#       min_y = -318.525 µm, max_y = 318.525 µm
#    t distribution: Gaussian
#       avg_t = 0 ps, sigma_t = 6.794 ps
#       Left n_sigma_cutoff = 3, Right n_sigma_cutoff = -3
#    px distribution: Gaussian
#       avg_px = 0 eV/c, sigma_px = 410.645 eV/c
#    py distribution: Gaussian
#       avg_py = 0 eV/c, sigma_py = 410.645 eV/c
#    pz distribution: Gaussian
#       avg_pz = 0 eV/c, sigma_pz = 410.645 eV/c
#    Shifting avg_x = 2.88034 µm -> 2.88034 µm
#    Shifting avg_y = 14.5416 µm -> 14.5416 µm
#    Shifting avg_px = -0.505043 eV/c -> 0 eV/c
#    Scaling sigma_px = 410.359 eV/c -> 410.645 eV/c
#    Shifting avg_py = -0.379762 eV/c -> 0 eV/c
#    Scaling sigma_py = 410.536 eV/c -> 410.645 eV/c
#    Shifting avg_pz = -0.592592 eV/c -> 0 eV/c
#    Scaling sigma_pz = 410.566 eV/c -> 410.645 eV/c
#    Shifting avg_t = -0.00501233 ps -> 0 ps
#    Scaling sigma_t = 6.70127 ps -> 6.70287 ps
#    Cathode start: fixing pz momenta to forward hemisphere
#       avg_pz -> 327.73 eV/c, sigma_pz -> 247.432 eV/c
# ...done. Time Elapsed: 455.516 ms.
#
#    Created particles in .particles:
#    ParticleGroup with 10000 particles with total charge 7.399763968000002e-11 C
# Autophase bookkeeper found settings, applying them
# Setting RFGUNB relative phase = 0.0 deg
# Found RFGUNB     relative phase = 0.00 deg
# Setting BUN1B relative phase = -57.0 deg
# Found BUN1B      relative phase = -57.00 deg
# Setting CAVL011 relative phase = -0.0014556840340716748 deg
# Found CAVL011    relative phase = -0.00 deg
# Setting CAVL012 relative phase = 0.0007059963906660277 deg
# Found CAVL012    relative phase = 0.00 deg
# Setting CAVL013 relative phase = -0.0008521047550363557 deg
# Found CAVL013    relative phase = -0.00 deg
# Setting CAVL014 relative phase = -0.0011352766350185006 deg
# Found CAVL014    relative phase = -0.00 deg
# Setting CAVL015 relative phase = -4.981843429976984e-05 deg
# Found CAVL015    relative phase = -0.00 deg
# Setting CAVL016 relative phase = -4.999397766240162 deg
# Found CAVL016    relative phase = -5.00 deg
# Setting CAVL017 relative phase = -12.400008096841498 deg
# Found CAVL017    relative phase = -12.40 deg
# Setting CAVL018 relative phase = 12.021884928172042 deg
# Found CAVL018    relative phase = 12.02 deg
# Running Impact-T in /sdf/home/m/mokun/SCRATCH/tmp_hw9x0dc
# salloc --partition milano --account ad:ard-online -N 1 -n 64 mpirun -n 64 /sdf/home/m/mokun/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# writing 10000 particles to /sdf/home/m/mokun/SCRATCH/tmp_hw9x0dc/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 10000 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 4.050318246839861e-11 according to initial particles
# Cathode start: Replaced Tini with -2.0290544042254925e-11 according to initial particles
# Changing particle offset factor zmu2 to 0
# Setting total charge to 7.399763968000002e-11 C
# Loaded fort 18 : Time and energy
# Loaded fort 24 : RMS X information
# Loaded fort 25 : RMS Y information
# Loaded fort 26 : RMS Z information
# Loaded fort 27 : Max amplitude information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 32 : Covariance matrix of the beam distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded write beam particles YAG01B fort.71
# Loaded write beam particles CM01BEG fort.72
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted YAG01B to ParticleGroup
# Converted CM01BEG to ParticleGroup
# 'final_particles'
# Something BAD happened. Sleeping for 10 s ...
# Acquired settings from EPICS at: 2024-11-13T17:10:18-08:00
# Waiting for good CAMR:LGUN:950:Image:ArrayData
# EPICS shapshot written: //sdf/home/m/mokun/lume-output/snapshot/2024/11/13/sc_inj-snapshot-2024-11-13T17:10:18-08:00.h5
# Running evaluate_impact_with_distgen...
# Setting distgen n_particle = 10000
# Setting impact timeout = 10000
# Setting impact header:Nx = 32
# Setting impact header:Ny = 32
# Setting impact header:Nz = 32
# Setting impact numprocs = 64
# Setting Npcol, Nprow = 8, 8
# Enabling MPI
# Setting impact command = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe
# Setting impact command_mpi = ~/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# Setting impact mpi_run = salloc --partition milano --account ad:ard-online -N 1 -n {nproc} mpirun -n {nproc} {command_mpi}
# Setting impact stop = 14
# Removed element: stop_1
# Set stop to s = 14
# Setting distgen t_dist:sigma_t:value = 6.794055201698514
# Setting impact RFGUNB:rf_field_scale = 16486924.441374516
# Setting impact RFGUNB:autophase_deg = 0.0
# Setting impact SOL1B:solenoid_field_scale = 0.05137057221689382
# Setting impact SOL2B:solenoid_field_scale = 0.02902505616926497
# Setting distgen total_charge:value = 73.51606784
# Setting impact BUN1B:rf_field_scale = 1696986.06875
# Setting impact BUN1B:autophase_deg = -57.0
# Setting impact CAVL011:rf_field_scale = 12119176.95089386
# Setting impact CAVL012:rf_field_scale = 9322056.70314095
# Setting impact CAVL013:rf_field_scale = 20323607.539168257
# Setting impact CAVL014:rf_field_scale = 9322199.050865578
# Setting impact CAVL015:rf_field_scale = 22934135.441592325
# Setting impact CAVL016:rf_field_scale = 30951734.73411214
# Setting impact CAVL017:rf_field_scale = 30019072.71745353
# Setting impact CAVL018:rf_field_scale = 30951643.06711819
# Setting impact CAVL011:autophase_deg = -0.0014587686239924402
# Setting impact CAVL012:autophase_deg = 0.0006951512978768185
# Setting impact CAVL013:autophase_deg = -0.0008579636034746745
# Setting impact CAVL014:autophase_deg = -0.0011312695753015467
# Setting impact CAVL015:autophase_deg = -5.1621808339202824e-05
# Setting impact CAVL016:autophase_deg = -4.999396870052685
# Setting impact CAVL017:autophase_deg = -12.500061544573358
# Setting impact CAVL018:autophase_deg = 12.116989388691506
# Setting impact Q0H01:b1_gradient = 2.010258163143016
# Setting impact Q0H02:b1_gradient = -1.8159181980356667
# Setting impact Q0H03:b1_gradient = -0.7905887537909446
# Setting impact Q0H04:b1_gradient = 1.5857686480197568
# Setting impact Q0H05:b1_gradient = 1.9303368766536333
# Setting impact Q0H06:b1_gradient = -0.5488832663841816
# Setting impact Q0H07:b1_gradient = -2.3054670099147954
# Setting impact Q0H08:b1_gradient = 2.4344040118425765
# Setting impact total_charge = 1
# Distribution format: None
#    Warning: no output file specified, defaulting to "None".
# Output file: None
#
# Creating beam distribution....
#    Beam starting from: cathode
#    Total charge: 73.5161 pC.
#    Number of macroparticles: 10000.
#    xy distribution: 2D File PDF
#       2D pdf file: //sdf/group/ad/sw/scm/repos/optics/lcls-lattice/distgen/models/sc_inj/vcc_image/laser_image.txt
#       min_x = -353.4 µm, max_x = 353.4 µm
#       min_y = -318.525 µm, max_y = 318.525 µm
#    t distribution: Gaussian
#       avg_t = 0 ps, sigma_t = 6.794 ps
#       Left n_sigma_cutoff = 3, Right n_sigma_cutoff = -3
#    px distribution: Gaussian
#       avg_px = 0 eV/c, sigma_px = 410.645 eV/c
#    py distribution: Gaussian
#       avg_py = 0 eV/c, sigma_py = 410.645 eV/c
#    pz distribution: Gaussian
#       avg_pz = 0 eV/c, sigma_pz = 410.645 eV/c
#    Shifting avg_x = 2.88034 µm -> 2.88034 µm
#    Shifting avg_y = 14.5416 µm -> 14.5416 µm
#    Shifting avg_px = -0.505043 eV/c -> 0 eV/c
#    Scaling sigma_px = 410.359 eV/c -> 410.645 eV/c
#    Shifting avg_py = -0.379762 eV/c -> 0 eV/c
#    Scaling sigma_py = 410.536 eV/c -> 410.645 eV/c
#    Shifting avg_pz = -0.592592 eV/c -> 0 eV/c
#    Scaling sigma_pz = 410.566 eV/c -> 410.645 eV/c
#    Shifting avg_t = -0.00501233 ps -> 0 ps
#    Scaling sigma_t = 6.70127 ps -> 6.70287 ps
#    Cathode start: fixing pz momenta to forward hemisphere
#       avg_pz -> 327.73 eV/c, sigma_pz -> 247.432 eV/c
# ...done. Time Elapsed: 311.559 ms.
#
#    Created particles in .particles:
#    ParticleGroup with 10000 particles with total charge 7.351606783999999e-11 C
# Autophase bookkeeper found settings, applying them
# Setting RFGUNB relative phase = 0.0 deg
# Found RFGUNB     relative phase = 0.00 deg
# Setting BUN1B relative phase = -57.0 deg
# Found BUN1B      relative phase = -57.00 deg
# Setting CAVL011 relative phase = -0.0014587686239924402 deg
# Found CAVL011    relative phase = -0.00 deg
# Setting CAVL012 relative phase = 0.0006951512978768185 deg
# Found CAVL012    relative phase = 0.00 deg
# Setting CAVL013 relative phase = -0.0008579636034746745 deg
# Found CAVL013    relative phase = -0.00 deg
# Setting CAVL014 relative phase = -0.0011312695753015467 deg
# Found CAVL014    relative phase = -0.00 deg
# Setting CAVL015 relative phase = -5.1621808339202824e-05 deg
# Found CAVL015    relative phase = -0.00 deg
# Setting CAVL016 relative phase = -4.999396870052685 deg
# Found CAVL016    relative phase = -5.00 deg
# Setting CAVL017 relative phase = -12.500061544573358 deg
# Found CAVL017    relative phase = -12.50 deg
# Setting CAVL018 relative phase = 12.116989388691506 deg
# Found CAVL018    relative phase = 12.12 deg
# Running Impact-T in /sdf/home/m/mokun/SCRATCH/tmpxs70n6pa
# salloc --partition milano --account ad:ard-online -N 1 -n 64 mpirun -n 64 /sdf/home/m/mokun/miniconda3/envs/lume-live-dev-jingyi-export/bin/ImpactTexe-mpi
# writing 10000 particles to /sdf/home/m/mokun/SCRATCH/tmpxs70n6pa/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 10000 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 4.050318246839861e-11 according to initial particles
# Cathode start: Replaced Tini with -2.0290544042254925e-11 according to initial particles
# Changing particle offset factor zmu2 to 0
# Setting total charge to 7.351606783999999e-11 C

# %%
## Notes from session with Jingyi
# environment2-jingyi-export.yml was created from jingyi's working env
# (before installing via the full export,
# ImpactTexe-mpi was throwing an error re: libcudart.so2, even if bin copied from her conda env)

# conda env create --name lume-live-dev-jingyi-export -f environment2-jingyi-export.yml 

# lume-live was not found in pypi, so we then installed it via:
# pip install git+https://github.com/slaclab/lcls-live


# mpi_run_cmd="salloc --partition milano --account ad:ard-online -N 1 -n {nproc} mpirun -n {nproc} {command_mpi}"

#
